# %% [markdown]
# ## Practice 1:
#
# ### Problem Statement:
# Analyze the housing dataset using various types of plots to gain insights into the data.

# %%
import pandas as pd
Housing_Data=pd.read_csv("housing_data.csv")
Housing_Data
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL         65.0     8450   Pave   NaN
# 1              1       SC20       RL         80.0     9600   Pave   NaN
# 2              2       SC60       RL         68.0    11250   Pave   NaN
# 3              3       SC70       RL         60.0     9550   Pave   NaN
# 4              4       SC60       RL         84.0    14260   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL         62.0     7917   Pave   NaN
# 1456        1456       SC20       RL         85.0    13175   Pave   NaN
# 1457        1457       SC70       RL         66.0     9042   Pave   NaN
# 1458        1458       SC20       RL         68.0     9717   Pave   NaN
# 1459        1459       SC20       RL         75.0     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL         65.0     8450   Pave   NaN      Reg
# 1           1       SC20       RL         80.0     9600   Pave   NaN      Reg
# 2           2       SC60       RL         68.0    11250   Pave   NaN      IR1
# 3           3       SC70       RL         60.0     9550   Pave   NaN      IR1
# 4           4       SC60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    729.500000    57.623288   10516.828082     6.099315     5.575342
# std     421.610009    34.664304    9981.264932     1.382997     1.112799
# min       0.000000     0.000000    1300.000000     1.000000     1.000000
# 25%     364.750000    42.000000    7553.500000     5.000000     5.000000
# 50%     729.500000    63.000000    9478.500000     6.000000     5.000000
# 75%    1094.250000    79.000000   11601.500000     7.000000     6.000000
# max    1459.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.117123   443.639726    46.549315  ...
# std      30.202904     20.645407   180.731373   456.098091   161.319273  ...
# ...

# %% [markdown]
# ## __Steps to Perform:__
# 1. Create a line plot to visualize the trend of house prices over the years.

# %%
import matplotlib.pyplot as plt

Housing_Data=pd.read_csv("housing_data.csv")
df=pd.DataFrame(Housing_Data)

plt.plot(df['SalePrice'])
plt.title("LinePlot: SalePrice")
plt.ylabel("Sale Price")
# Out:
# Text(0, 0.5, 'Sale Price')

# %% [markdown]
# 2. Use a scatter plot to visualize the relationship between two numerical variables, such as __LotArea__ and __SalePrice__.

# %%
import matplotlib.pyplot as plt
Sqft=df['LotArea']
SalePrice=df['SalePrice']
plt.scatter(Sqft,SalePrice,c=Sqft,cmap="viridis")
plt.title("Scatter plot to compare Area with Price")
plt.xlabel("Area(Sqft)")
plt.ylabel("Price")

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# 3. Create a bar chart to show the count of houses in each __Neighborhood__.

# %%
# Count the occurrences of each neighborhood
neighborhood_counts = df["Neighborhood"].value_counts()

# Create a bar chart
plt.figure(figsize=(12, 6))
neighborhood_counts.plot(kind="bar", color="skyblue", edgecolor="black")

# Formatting the plot
plt.xlabel("Neighborhood")
plt.ylabel("Number of Houses")
plt.title("Count of Houses in Each Neighborhood")
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels for readability

# Show the plot
plt.show()

# %% [markdown]
# 4. Use a box plot to visualize the distribution of __SalePrice__ in each __Neighborhood__.

# %%
# Create a box plot using pandas
plt.figure(figsize=(16, 6))
df.boxplot(column="SalePrice", by="Neighborhood", grid=False, vert=True, figsize=(16, 6), patch_artist=True)

# Formatting the plot
plt.xlabel("Neighborhood")
plt.ylabel("Sale Price")
plt.title("Distribution of SalePrice in Each Neighborhood")
plt.suptitle("")  # Remove default Pandas title
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels for readability

# Show the plot
plt.show()

# %% [markdown]
# 5. Create a pie chart to visualize the proportion of houses that fall into each __MSZoning__ category.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#read the csv file into a pandas dataframe and parsing dates
df=pd.read_csv("housing_data.csv",parse_dates=True)

df['MSZoning'].value_counts()
# Out:
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each zoning category
zoning_counts = df["MSZoning"].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(zoning_counts, labels=zoning_counts.index, autopct="%1.1f%%", startangle=140, colors=plt.cm.Paired.colors)
plt.title("Proportion of Houses in Each MSZoning Category")
plt.show()

# %% [markdown]
# 6. Use a 3D scatter plot to visualize __LotArea__, __OverallQual__, and __SalePrice__ together.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#read the csv file into a pandas dataframe and parsing dates
df=pd.read_csv("housing_data.csv",parse_dates=True)

df.columns
# Out:
# Index(['Unnamed: 0', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea',
#        'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
# Create a 3D scatter plot
ax = plt.axes(projection='3d')
ax.scatter(df['LotArea'], df['OverallQual'], df['SalePrice'])

# Set labels for each axis
ax.set_xlabel('Area in sqft')
ax.set_ylabel('Overall_Quality')
ax.set_zlabel('SalePrice')

# Display the 3D scatter plot
plt.show()
